# %%
def findOddOneOut(dataList):

    for i, j in enumerate(dataList):

        if j % 2 != 0:
            print(f'Find odd number at index{i}')
            return j

        else:
            print(f'Checked index {i}: even. Continue')

    return 'Error no odd number was found.'

dl = dataList()
dl = [2, 4, 6, 8, 10, 5, 14]
odd_number = findOddOneOut(dl)
print("\n--- Result ---")
print(f"Input List: {dl}")
print(f"The odd integer (Output): {odd_number}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      10             print(f'Checked index {i}: even. Continue')
#      12     return 'Error no odd number was found.'
# ---> 14 dl = dataList()
#      15 dl = [2, 4, 6, 8, 10, 5, 14]
#      16 odd_number = findOddOneOut(dl)
#
# NameError: name 'dataList' is not defined
