# %%
#create hash table
class hashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size) ]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        print(f'{key}--->{index}')
        self.table[index].append((key, value))

hT = hashTable(10)

hT.insert('John Doe', 30)
hT.insert('John Smith', 25)
hT.insert('Alice John', 35)
hT.insert('Bob Brown', 40)
hT.insert('Emily Davis', 28)
hT.insert('Michael Wilson', 32)
# Out:
# John Doe--->6
# John Smith--->8
# Alice John--->7
# Bob Brown--->5
# Emily Davis--->4
# Michael Wilson--->6

# %%
hT.table
# Out:
# [[],
#  [],
#  [],
#  [],
#  [('Emily Davis', 28)],
#  [('Bob Brown', 40)],
#  [('John Doe', 30), ('Michael Wilson', 32)],
#  [('Alice John', 35)],
#  [('John Smith', 25)],
#  []]

# %%
class hashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        print(f'{key}--->{index}')
        self.table[index].append((key, value))

hT = hashTable(10)
hT.insert('John Doe', 30)
hT.insert('John Smith', 25)
hT.insert('Alice John', 35)
hT.insert('Bob Brown', 40)
hT.insert('Emily Davis', 28)
hT.insert('Michael Wilson', 32)
# Out:
# John Doe--->6
# John Smith--->8
# Alice John--->7
# Bob Brown--->5
# Emily Davis--->4
# Michael Wilson--->6

# %%
hT.table #having hash collision john doe and michael
# Out:
# [[],
#  [],
#  [],
#  [],
#  [('Emily Davis', 28)],
#  [('Bob Brown', 40)],
#  [('John Doe', 30), ('Michael Wilson', 32)],
#  [('Alice John', 35)],
#  [('John Smith', 25)],
#  []]

# %%
#hash collision solve linear probing

# %%
class hashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        print(f'{key}--->{index}', end = '')

        start_index = index
        while self.table[index] is not None and self.table[index][0] != 0:
            print(f'collision at {index}', end = '')
            index = (index + 1) % self.size
            if index == start_index:
                print('hash table is full')
                return

        self.table[index] = (key, value)
        print(f'-->placed at {index}')

    def display(self):
        for i, item in enumerate(self.table):
            print(f'{i}:{item}')

hT = hashTable(10)
hT.insert('John Doe', 30)
hT.insert('John Smith', 25)
hT.insert('Alice John', 35)
hT.insert('Bob Brown', 40)
hT.insert('Emily Davis', 28)
hT.insert('Michael Wilson', 32)

print("\nHash Table:")
hT.display()
# Out:
# John Doe--->6-->placed at 6
# John Smith--->8-->placed at 8
# Alice John--->7-->placed at 7
# Bob Brown--->5-->placed at 5
# Emily Davis--->4-->placed at 4
# Michael Wilson--->6collision at 6collision at 7collision at 8-->placed at 9
#
# Hash Table:
# 0:None
# 1:None
# 2:None
# 3:None
# 4:('Emily Davis', 28)
# 5:('Bob Brown', 40)
# 6:('John Doe', 30)
# 7:('Alice John', 35)
# 8:('John Smith', 25)
# 9:('Michael Wilson', 32)

# %%
#two sums

# %%
def twoSum(nums, target):
    hash_table = {}

    for i, num in enumerate(nums):
        complement = target - num
        if complement in hash_table:
            return [hash_table[complement], i]
        hash_table[num] = i

print(twoSum([2, 7, 11, 15], 9))   
print(twoSum([3, 2, 4], 6))        
print(twoSum([3, 3], 6))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]
